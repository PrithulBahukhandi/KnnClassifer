# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
from math import sqrt
import random

# calculating euclidian distance between 2 points

def euclidean_distance(row1, row2):
    distance = 0.0
    for i in range(len(row1)-1):
        distance += (row1[i] - row2[i])**2
    return sqrt(distance)

# locate k nearest neighbors
def find_neighbor(train, test, k):
    distances = list()
    for row in train:
        dist = euclidean_distance(test,row)
        distances.append((row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbors = list()

    for i in range(k):
        neighbors.append(distances[i][0])
    return neighbors

# this is my knn function
def myknnclassify(train, test, k):
    neighbors = find_neighbor(train, test, k)
    print('test point is ',test)
    output_values = [row[-1] for row in neighbors]
    prediction = max(set(output_values), key=output_values.count)
    return neighbors,prediction


# this is my Locally weighted regression  function
def myLWR(train, test, k):
    calcDist,neighbors = myLWR_neighbors(train, test, k)

    print('test point is ',test)
#     print(neighbors)
    output_values = [row[-1] for row in neighbors]
    prediction = max(set(output_values), key=output_values.count)
    return neighbors,prediction,calcDist

mu1=[1,0]
mu2=[0,1]
sigma1=[[1,0.75],[0.75,1]]
sigma2=[[1,-0.5],[0.5,1]]
    
x1= np.random.multivariate_normal(mu1,sigma1,200)
y1 = np.random.randint(0,1,(200,1))
x1=np.append(x1, y1, axis=1)

x2= np.random.multivariate_normal(mu2,sigma2,200)
y2 = np.random.randint(1,2,(200,1))
x2=np.append(x2, y2, axis=1)

t1= np.random.multivariate_normal(mu1,sigma1,50)
yrand1=np.random.randint(0,2,(50,1))
t1=np.append(t1, yrand1, axis=1)
t2= np.random.multivariate_normal(mu2,sigma2,50)
yrand2=np.random.randint(0,2,(50,1))
t2=np.append(t2, yrand2, axis=1)
test= np.concatenate((t1, t2))



    
# x2= np.random.multivariate_normal(mu2,sigma2,200)
    
train = np.concatenate((x1, x2))

for k in [1,2,3,4,5,10,20]:
    print('\033[1m'+'k is ',k,'\033[0m')
    for row in test:
        neighbors,prediction = myknnclassify(train, row, k)
        
        print('closest k neighbors are ')
        for n in neighbors:
            print(n)
            
        print('predicted class= ',prediction)
        print('actual class= ',row[2])
        if(prediction==row[2]):
            print('accuracy= 100%')
        else:
            print('accuracy= 0%')
        print("\n")
# Out:
# <ipython-input-1-665926c29e9a>:57: RuntimeWarning: covariance is not positive-semidefinite.
#   x2= np.random.multivariate_normal(mu2,sigma2,200)
# <ipython-input-1-665926c29e9a>:64: RuntimeWarning: covariance is not positive-semidefinite.
#   t2= np.random.multivariate_normal(mu2,sigma2,50)
# k is  1
# test point is  [1.00557031 0.73578327 1.        ]
# closest k neighbors are
# [0.8885302  0.72194721 0.        ]
# predicted class=  0.0
# actual class=  1.0
# accuracy= 0%
#
#
# test point is  [1.37411329 1.00875154 1.        ]
# closest k neighbors are
# [1.35125463 1.01847789 1.        ]
# predicted class=  1.0
# actual class=  1.0
# accuracy= 100%
#
#
# test point is  [-0.41400067 -1.37806517  1.        ]
# closest k neighbors are
# [-0.51800756 -1.2055677   0.        ]
# predicted class=  0.0
# actual class=  1.0
# accuracy= 0%
#
#
# test point is  [1.85295437 0.27674926 0.        ]
# closest k neighbors are
# [1.86179298 0.28385069 1.        ]
# predicted class=  1.0
# ...
